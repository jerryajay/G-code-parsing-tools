# %%
import os
import re
import csv

# %%
from g_code_parser import init_csv_file

# %%
init_csv_file()

# %%
path_gcode = "/media/jerryant/69a88f67-cccc-4d4c-8ce5-161e5a3cc104/JERRY/GCODES/Gcode-infill-grid-files/Gcode-files/"

# %%
from g_code_parser import process_gcode_file

# %%
for filename in os.listdir(path_gcode):
    print "Processing:", filename
    process_gcode_file(path_gcode+filename)
print "Completely Done"
# Out:
# Processing: NEW_DISK.stl.gcode
# Processed: /media/jerryant/69a88f67-cccc-4d4c-8ce5-161e5a3cc104/JERRY/GCODES/Gcode-infill-grid-files/Gcode-files/NEW_DISK.stl.gcode
# Processing: divided_case_v1-1_20150508-3223-rhbjqt-0.stl.gcode
# Processed: /media/jerryant/69a88f67-cccc-4d4c-8ce5-161e5a3cc104/JERRY/GCODES/Gcode-infill-grid-files/Gcode-files/divided_case_v1-1_20150508-3223-rhbjqt-0.stl.gcode
# Processing: fullyprintableparametricmusicbox_20150508-8710-1t13g3y-0.stl.gcode
# Processed: /media/jerryant/69a88f67-cccc-4d4c-8ce5-161e5a3cc104/JERRY/GCODES/Gcode-infill-grid-files/Gcode-files/fullyprintableparametricmusicbox_20150508-8710-1t13g3y-0.stl.gcode
# Processing: firepit.stl.gcode
# Processed: /media/jerryant/69a88f67-cccc-4d4c-8ce5-161e5a3cc104/JERRY/GCODES/Gcode-infill-grid-files/Gcode-files/firepit.stl.gcode
# Processing: epcot-style_v1_0_20150508-8757-1wytogx-0.stl.gcode
# ...
